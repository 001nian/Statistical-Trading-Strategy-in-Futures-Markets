# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from datetime import datetime

data = pd.read_csv("./data/HO-5min.csv", parse_dates=[['Date', 'Time']])
data
# Out:
#                  Date_Time    Open    High     Low   Close  Volume
# 0      1984-01-03 10:10:00  1.2543  1.2568  1.2538  1.2568       0
# 1      1984-01-03 10:15:00  1.2568  1.2573  1.2563  1.2563       0
# 2      1984-01-03 10:20:00  1.2563  1.2568  1.2558  1.2568       0
# 3      1984-01-03 10:25:00  1.2563  1.2563  1.2538  1.2538       0
# 4      1984-01-03 10:30:00  1.2533  1.2533  1.2513  1.2513       0
# ...                    ...     ...     ...     ...     ...     ...
# 612491 2023-04-06 14:10:00  4.3721  4.3745  4.3692  4.3724     189
# 612492 2023-04-06 14:15:00  4.3734  4.3741  4.3659  4.3673     328
# 612493 2023-04-06 14:20:00  4.3688  4.3703  4.3628  4.3661     554
# 612494 2023-04-06 14:25:00  4.3660  4.3690  4.3634  4.3645     509
# 612495 2023-04-06 14:30:00  4.3654  4.3682  4.3595  4.3606    3141
#
# [612496 rows x 6 columns]

# %%
# Read the data
df = data

# Set the index to the "Date_Time" column
df.set_index("Date_Time", inplace=True)

# Plot the "Close" column
df["Close"].plot()

# Set the title and labels
plt.title("Price of HO vs Time (5 min intervals)")
plt.xlabel("Date_Time")
plt.ylabel("Close Price")

# Show the plot
plt.show()

# %%
# Calculate the average price change per 5 mins
avg_price_change = df["Close"].diff().mean()

# Calculate the standard deviation of price
std_price = df["Close"].std()

# Calculate the average price of ticker
avg_price = df["Close"].mean()

# Calculate the max price and the date_time then
max_price = df["Close"].max()
max_price_date = df["Close"].idxmax()

# Calculate the min price and the date_time then
min_price = df["Close"].min()
min_price_date = df["Close"].idxmin()

# Calculate the max 5-min price increase
max_price_increase = df["Close"].diff().max()

# Calculate the min 5-min price decrease
min_price_decrease = df["Close"].diff().min()

# Print out the results
print("Average price change per 5 mins:", avg_price_change)
print("Standard deviation of price per 5 mins:", std_price)
print("Average price of ticker:", avg_price)
print("Max price:", max_price, "on", max_price_date)
print("Min price:", min_price, "on", min_price_date)
print("Max 5-min price increase:", max_price_increase)
print("Min 5-min price decrease:", min_price_decrease)
# Out:
# Average price change per 5 mins: 5.06746993853011e-06
# Standard deviation of price per 5 mins: 0.820672387147515
# Average price of ticker: 2.0805955434811008
# Max price: 5.2158 on 2022-11-04 13:40:00
# Min price: 0.6427 on 2020-04-27 14:20:00
# Max 5-min price increase: 0.4108999999999998
# Min 5-min price decrease: -0.5349999999999997

# %%
data = pd.read_csv("./data/HO-15min.csv", parse_dates=[['Date', 'Time']])
data
# Out:
#                  Date_Time    Open    High     Low   Close  Volume
# 0      1984-01-03 10:15:00  1.2543  1.2573  1.2538  1.2563       0
# 1      1984-01-03 10:30:00  1.2563  1.2568  1.2513  1.2513       0
# 2      1984-01-03 10:45:00  1.2523  1.2543  1.2508  1.2528       0
# 3      1984-01-03 11:00:00  1.2533  1.2553  1.2528  1.2533       0
# 4      1984-01-03 11:15:00  1.2538  1.2538  1.2518  1.2528       0
# ...                    ...     ...     ...     ...     ...     ...
# 205817 2023-04-21 13:30:00  4.1956  4.1995  4.1942  4.1957     386
# 205818 2023-04-21 13:45:00  4.1957  4.2044  4.1957  4.2021     263
# 205819 2023-04-21 14:00:00  4.2016  4.2059  4.1993  4.2023     414
# 205820 2023-04-21 14:15:00  4.2025  4.2076  4.1992  4.2072     639
# 205821 2023-04-21 14:30:00  4.2073  4.2085  4.1997  4.2042    2670
#
# [205822 rows x 6 columns]

# %%
# Read the data
df = data

# Set the index to the "Date_Time" column
df.set_index("Date_Time", inplace=True)

# Plot the "Close" column
df["Close"].plot()

# Set the title and labels
plt.title("Price of HO vs Time (15 min intervals)")
plt.xlabel("Date_Time")
plt.ylabel("Close Price")

# Show the plot
plt.show()

# %%
# Calculate the average price change per 15 mins
avg_price_change = df["Close"].diff().mean()

# Calculate the standard deviation of price
std_price = df["Close"].std()

# Calculate the average price of ticker
avg_price = df["Close"].mean()

# Calculate the max price and the date_time then
max_price = df["Close"].max()
max_price_date = df["Close"].idxmax()

# Calculate the min price and the date_time then
min_price = df["Close"].min()
min_price_date = df["Close"].idxmin()

# Calculate the max 15-min price increase
max_price_increase = df["Close"].diff().max()

# Calculate the min 15-min price decrease
min_price_decrease = df["Close"].diff().min()

# Print out the results
print("Average price change per 15 mins:", avg_price_change)
print("Standard deviation of price per 15 mins:", std_price)
print("Average price of ticker:", avg_price)
print("Max price:", max_price, "on", max_price_date)
print("Min price:", min_price, "on", min_price_date)
print("Max 15-min price increase:", max_price_increase)
print("Min 15-min price decrease:", min_price_decrease)
# Out:
# Average price change per 15 mins: 1.4322639575164828e-05
# Standard deviation of price per 15 mins: 0.8225495898259614
# Average price of ticker: 2.0786790896988663
# Max price: 5.212 on 2022-11-04 13:45:00
# Min price: 0.6442 on 2020-04-27 14:15:00
# Max 15-min price increase: 0.41140000000000043
# Min 15-min price decrease: -0.5692999999999997

# %%
data = pd.read_csv("./data/COKE-5min.csv", parse_dates=[['Date', 'Time']])
data
# Out:
#                 Date_Time    Open    High     Low   Close  Volume
# 0     2018-05-03 09:05:00   293.0   294.5   282.5   285.5    1546
# 1     2018-05-03 09:10:00   285.5   286.0   281.5   285.5    1518
# 2     2018-05-03 09:15:00   285.5   293.5   284.5   293.5    1396
# 3     2018-05-03 09:20:00   293.5   293.5   290.0   291.0    1150
# 4     2018-05-03 09:25:00   290.5   294.0   290.0   292.0     768
# ...                   ...     ...     ...     ...     ...     ...
# 86395 2023-04-07 14:40:00  2546.0  2546.5  2541.0  2543.0     125
# 86396 2023-04-07 14:45:00  2543.5  2551.0  2543.5  2548.5      92
# 86397 2023-04-07 14:50:00  2548.0  2549.5  2544.0  2546.0      82
# 86398 2023-04-07 14:55:00  2546.0  2547.5  2543.5  2544.0     109
# 86399 2023-04-07 15:00:00  2544.0  2548.5  2537.5  2542.0     272
#
# [86400 rows x 6 columns]

# %%
# Read the data
df = data

# Set the index to the "Date_Time" column
df.set_index("Date_Time", inplace=True)

# Plot the "Close" column
df["Close"].plot()

# Set the title and labels
plt.title("Price of COKE vs Time (5 min intervals)")
plt.xlabel("Date_Time")
plt.ylabel("Close Price")

# Show the plot
plt.show()

# %%
# Calculate the average price change per 5 mins
avg_price_change = df["Close"].diff().mean()

# Calculate the standard deviation of price
std_price = df["Close"].std()

# Calculate the average price of ticker
avg_price = df["Close"].mean()

# Calculate the max price and the date_time then
max_price = df["Close"].max()
max_price_date = df["Close"].idxmax()

# Calculate the min price and the date_time then
min_price = df["Close"].min()
min_price_date = df["Close"].idxmin()

# Calculate the max 5-min price increase
max_price_increase = df["Close"].diff().max()

# Calculate the min 5-min price decrease
min_price_decrease = df["Close"].diff().min()

# Print out the results
print("Average price change per 5 mins:", avg_price_change)
print("Standard deviation of price per 5 mins:", std_price)
print("Average price of ticker:", avg_price)
print("Max price:", max_price, "on", max_price_date)
print("Min price:", min_price, "on", min_price_date)
print("Max 5-min price increase:", max_price_increase)
print("Min 5-min price decrease:", min_price_decrease)
# Out:
# Average price change per 5 mins: 0.02611720043056054
# Standard deviation of price per 5 mins: 935.9957385270317
# Average price of ticker: 1430.5000810185186
# Max price: 3798.5 on 2022-04-19 10:05:00
# Min price: 245.0 on 2018-05-23 13:30:00
# Max 5-min price increase: 238.5
# Min 5-min price decrease: -365.0

# %%
data = pd.read_csv("./data/COKE-15min.csv", parse_dates=[['Date', 'Time']])
data
# Out:
#                 Date_Time    Open    High     Low   Close  Volume
# 0     2018-05-03 09:15:00   130.5   132.0   119.0   131.0    4460
# 1     2018-05-03 09:30:00   131.0   139.0   127.5   132.0    3358
# 2     2018-05-03 09:45:00   132.5   134.5   128.0   129.5    2838
# 3     2018-05-03 10:00:00   129.5   130.0   121.5   124.0    3486
# 4     2018-05-03 10:15:00   124.0   126.5   121.0   123.5    2032
# ...                   ...     ...     ...     ...     ...     ...
# 29035 2023-04-21 14:00:00  2281.5  2290.0  2280.0  2281.0     398
# 29036 2023-04-21 14:15:00  2282.0  2287.0  2277.0  2284.0     279
# 29037 2023-04-21 14:30:00  2284.0  2284.5  2275.0  2275.0     310
# 29038 2023-04-21 14:45:00  2275.0  2280.5  2273.5  2274.0     377
# 29039 2023-04-21 15:00:00  2274.0  2278.5  2268.0  2274.5     668
#
# [29040 rows x 6 columns]

# %%
# Read the data
df = data

# Set the index to the "Date_Time" column
df.set_index("Date_Time", inplace=True)

# Plot the "Close" column
df["Close"].plot()

# Set the title and labels
plt.title("Price of COKE vs Time (15 min intervals)")
plt.xlabel("Date_Time")
plt.ylabel("Close Price")

# Show the plot
plt.show()

# %%
# Calculate the average price change per 15 mins
avg_price_change = df["Close"].diff().mean()

# Calculate the standard deviation of price
std_price = df["Close"].std()

# Calculate the average price of ticker
avg_price = df["Close"].mean()

# Calculate the max price and the date_time then
max_price = df["Close"].max()
max_price_date = df["Close"].idxmax()

# Calculate the min price and the date_time then
min_price = df["Close"].min()
min_price_date = df["Close"].idxmin()

# Calculate the max 15-min price increase
max_price_increase = df["Close"].diff().max()

# Calculate the min 15-min price decrease
min_price_decrease = df["Close"].diff().min()

# Print out the results
print("Average price change per 15 mins:", avg_price_change)
print("Standard deviation of price per 15 mins:", std_price)
print("Average price of ticker:", avg_price)
print("Max price:", max_price, "on", max_price_date)
print("Min price:", min_price, "on", min_price_date)
print("Max 15-min price increase:", max_price_increase)
print("Min 15-min price decrease:", min_price_decrease)
# Out:
# Average price change per 15 mins: 0.07381452529357072
# Standard deviation of price per 15 mins: 937.1369281667783
# Average price of ticker: 1276.8529614325068
# Max price: 3631.5 on 2022-04-19 10:15:00
# Min price: 82.5 on 2018-05-23 13:30:00
# Max 15-min price increase: 213.0
# Min 15-min price decrease: -365.0

# %% [markdown]
# # Variance Ratio Test

# %% [markdown]
# ## 1. Andrew Lo's Variance Ratio Test

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def variance_ratio(close_prices, k):
    close_prices = np.asarray(close_prices)
    one_volatility = np.std(np.diff(close_prices))
    k_volatility = np.std(close_prices[k:] - close_prices[:-k])
    return (k_volatility / (one_volatility * np.sqrt(k))) ** 2

file_path = "./data/HO-5min.csv"
data = pd.read_csv(file_path)
close_prices = data['Close']

lags = list(range(1, 10000))
ratios = [variance_ratio(close_prices, lag) for lag in lags]

plt.plot(lags, ratios, label='Variance Ratios')
plt.axhline(y=1, color='r', linestyle='--', label='Theoretical Value')
plt.xlabel('q values(minutes)')
plt.ylabel('Variance Ratio')
plt.title('Variance Ratio Test for HO (5-min) Futures')
plt.legend()
plt.show()

# %%
file_path = "./data/HO-15min.csv"
data = pd.read_csv(file_path)
close_prices = data['Close']

lags = list(range(1, 10000))
ratios = [variance_ratio(close_prices, lag) for lag in lags]

plt.plot(lags, ratios, label='Variance Ratios')
plt.axhline(y=1, color='r', linestyle='--', label='Theoretical Value')
plt.xlabel('q values(minutes)')
plt.ylabel('Variance Ratio')
plt.title('Variance Ratio Test for HO (15-min) Futures')
plt.legend()
plt.show()

# %%
file_path = "./data/COKE-5min.csv"
data = pd.read_csv(file_path)
close_prices = data['Close']

lags = list(range(1, 10000))
ratios = [variance_ratio(close_prices, lag) for lag in lags]

plt.plot(lags, ratios, label='Variance Ratios')
plt.axhline(y=1, color='r', linestyle='--', label='Theoretical Value')
plt.xlabel('q values(minutes)')
plt.ylabel('Variance Ratio')
plt.title('Variance Ratio Test for COKE (5-min) Futures')
plt.legend()
plt.show()

# %%
file_path = "./data/COKE-15min.csv"
data = pd.read_csv(file_path)
close_prices = data['Close']

lags = list(range(1, 10000))
ratios = [variance_ratio(close_prices, lag) for lag in lags]

plt.plot(lags, ratios, label='Variance Ratios')
plt.axhline(y=1, color='r', linestyle='--', label='Theoretical Value')
plt.xlabel('q values(minutes)')
plt.ylabel('Variance Ratio')
plt.title('Variance Ratio Test for COKE 15-min Futures')
plt.legend()
plt.show()

# %% [markdown]
# ## 2. (Optional Extra) Chow Dennigs Variance Ratio Test

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
from datetime import datetime

data = pd.read_csv("./data/COKE-5min.csv", parse_dates=[['Date', 'Time']]).dropna()
data
# Out:
#                 Date_Time    Open    High     Low   Close  Volume
# 0     2018-05-03 09:05:00   293.0   294.5   282.5   285.5    1546
# 1     2018-05-03 09:10:00   285.5   286.0   281.5   285.5    1518
# 2     2018-05-03 09:15:00   285.5   293.5   284.5   293.5    1396
# 3     2018-05-03 09:20:00   293.5   293.5   290.0   291.0    1150
# 4     2018-05-03 09:25:00   290.5   294.0   290.0   292.0     768
# ...                   ...     ...     ...     ...     ...     ...
# 86395 2023-04-07 14:40:00  2546.0  2546.5  2541.0  2543.0     125
# 86396 2023-04-07 14:45:00  2543.5  2551.0  2543.5  2548.5      92
# 86397 2023-04-07 14:50:00  2548.0  2549.5  2544.0  2546.0      82
# 86398 2023-04-07 14:55:00  2546.0  2547.5  2543.5  2544.0     109
# 86399 2023-04-07 15:00:00  2544.0  2548.5  2537.5  2542.0     272
#
# [86400 rows x 6 columns]

# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import scipy.stats as sps

# %%
import warnings
warnings.filterwarnings("ignore")
max_t = 10000
prices = data["Close"]
returns = prices.pct_change()[1:]
n = len(returns)
variance_0 = returns.var()
variance_ratio_output = pd.DataFrame()
for t in np.arange(2, max_t+1):
    variance = returns.rolling(t).sum().var()
    variance_ratio = variance/(variance_0*t) - 1
    standard_error = (2*(2*t - 1)*(t-1)/(3*t*n))**(1/2)
    z_stat = variance_ratio/standard_error
    p_value = 2*(1 - sps.norm.cdf(abs(z_stat)))
    variance_ratio_output[t] = [round(variance_0, 6), round(variance, 6), round(variance_ratio, 4), round(standard_error, 4), round(z_stat, 4), p_value]
plt.plot(variance_ratio_output.iloc[4])
min_pvalue = min(variance_ratio_output.iloc[5])
max_z_stat = variance_ratio_output.iloc[4][variance_ratio_output.iloc[5] == min_pvalue].values[0]
Chow_Denning = 1 - (1 - min_pvalue)**(max_t)
if Chow_Denning > 0.1:
    print('the market is efficient')
elif max_z_stat > 0:
    print('the market is trending')
else:
    print('the market is mean-reverting')
# Out:
# the market is mean-reverting

# %% [markdown]
# # Push Response Test

# %%
# This can be found in the separate regressional analysis file in the form of R code
